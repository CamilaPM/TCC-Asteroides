# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 1
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 1
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_speca = m.flux(albedo, diametro, wavelengths=wave)
thermal_speca.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 1.3
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 1.3
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specb = m.flux(albedo, diametro, wavelengths=wave)
thermal_specb.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 1.6
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 1.6
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specc = m.flux(albedo, diametro, wavelengths=wave)
thermal_specc.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 1.9
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 1.9
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specd = m.flux(albedo, diametro, wavelengths=wave)
thermal_specd.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.1
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.1
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_spece = m.flux(albedo, diametro, wavelengths=wave)
thermal_spece.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.4
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.4
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specf = m.flux(albedo, diametro, wavelengths=wave)
thermal_specf.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.7
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.7
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specg = m.flux(albedo, diametro, wavelengths=wave)
thermal_specg.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 3
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 3
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_spech = m.flux(albedo, diametro, wavelengths=wave)
thermal_spech.plot()

# %%
#Dados do Svea (da NASA) variando a distância do Sol - todos juntos

import matplotlib
import matplotlib.pyplot as plt
import numpy 
import numpy as np


matplotlib.pyplot.title("Asteroide Svea variando a distância dele ao Sol")
matplotlib.pyplot.xlim(0.4,5.05)
matplotlib.pyplot.ylim(-0.1,10.0)

matplotlib.pyplot.xlabel("Wavelength")
matplotlib.pyplot.ylabel("Reflectance")

plt.plot(thermal_speca.w, thermal_speca.r,"lime",lw=1.5,linestyle="solid")#b de azul e dashed de tracejado
plt.plot(thermal_specb.w, thermal_specb.r,"orange",lw=1.5,linestyle="solid")#r de vermelho e dotted de pontilhado
plt.plot(thermal_specc.w, thermal_specc.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specd.w, thermal_specd.r,"green",lw=1.5,linestyle="solid") #legenda
plt.plot(thermal_spece.w, thermal_spece.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specf.w, thermal_specf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specg.w, thermal_specg.r,"deeppink",lw=1.5,linestyle="solid") #deeppink é um rosa forte
plt.plot(thermal_spech.w, thermal_spech.r,"brown",lw=1.5,linestyle="solid")

plt.legend(["1.0 UA", "1.3 UA", "1.6 UA", "1.9 UA", "2.1 UA", "2.4 UA", "2.7 UA", "3.0 UA"], 
           loc = "upper left", bbox_to_anchor=(1, 1), shadow = True)


plt.plot(thermal_speca.w, thermal_speca.r,"lime",lw=1.5,linestyle="solid")
plt.plot(thermal_specb.w, thermal_specb.r,"orange",lw=1.5,linestyle="solid")
plt.plot(thermal_specc.w, thermal_specc.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specd.w, thermal_specd.r,"green",lw=1.5,linestyle="solid")
plt.plot(thermal_spece.w, thermal_spece.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specf.w, thermal_specf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specg.w, thermal_specg.r,"deeppink",lw=1.5,linestyle="solid")
plt.plot(thermal_spech.w, thermal_spech.r,"brown",lw=1.5,linestyle="solid")

plt.figure(figsize=(20, 12))

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 0.002

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 0.002
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaa = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaa.plot()
# Out:
# /home/camila/.local/lib/python3.6/site-packages/cana/thermal/models.py:32: RuntimeWarning: overflow encountered in exp
#   aux = np.exp(h_planck * c_light / k_bol / wavelength / temp)

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 0.02

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 0.02
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specab = m.flux(albedo, diametro, wavelengths=wave)
thermal_specab.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 0.2

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 0.2
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specac = m.flux(albedo, diametro, wavelengths=wave)
thermal_specac.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 0.6

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 0.6
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specad = m.flux(albedo, diametro, wavelengths=wave)
thermal_specad.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specae = m.flux(albedo, diametro, wavelengths=wave)
thermal_specae.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.4

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.4
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaf = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaf.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.9

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.9
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specag = m.flux(albedo, diametro, wavelengths=wave)
thermal_specag.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 2.3

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 2.3
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specah = m.flux(albedo, diametro, wavelengths=wave)
thermal_specah.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 2.7

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 2.7
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specai = m.flux(albedo, diametro, wavelengths=wave)
thermal_specai.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 3

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 3
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaj = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaj.plot()

# %%
#Dados do Svea (da NASA) variando a distância da Terra - todos juntos

import matplotlib
import matplotlib.pyplot as plt
import numpy 
import numpy as np


matplotlib.pyplot.title("Asteroide Svea variando a distância dele à Terra")
matplotlib.pyplot.xlim(0.4,5.05)
matplotlib.pyplot.ylim(-0.1,10.0)

matplotlib.pyplot.xlabel("Wavelength")
matplotlib.pyplot.ylabel("Reflectance")

plt.plot(thermal_specaa.w, thermal_specaa.r,"lime",lw=1.5,linestyle="solid")#b de azul e dashed de tracejado
plt.plot(thermal_specab.w, thermal_specab.r,"orange",lw=1.5,linestyle="solid")#r de vermelho e dotted de pontilhado
plt.plot(thermal_specac.w, thermal_specac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specad.w, thermal_specad.r,"green",lw=1.5,linestyle="solid") #legenda
plt.plot(thermal_specae.w, thermal_specae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaf.w, thermal_specaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specag.w, thermal_specag.r,"deeppink",lw=1.5,linestyle="solid") #deeppink é um rosa forte
plt.plot(thermal_specah.w, thermal_specah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specai.w, thermal_specai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaj.w, thermal_specaj.r,"gray",lw=1.5,linestyle="solid")

plt.legend(["0.002 UA", "0.020 UA", "0.200 UA", "0.600 UA", "1.000 UA", "1.400 UA", "1.900 UA", "2.300 UA", "2.700 UA", "3.000 UA"], 
           loc = "upper left", bbox_to_anchor=(1, 1), shadow = True)


plt.plot(thermal_specaa.w, thermal_specaa.r,"lime",lw=1.5,linestyle="solid")
plt.plot(thermal_specab.w, thermal_specab.r,"orange",lw=1.5,linestyle="solid")
plt.plot(thermal_specac.w, thermal_specac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specad.w, thermal_specad.r,"green",lw=1.5,linestyle="solid")
plt.plot(thermal_specae.w, thermal_specae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaf.w, thermal_specaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specag.w, thermal_specag.r,"deeppink",lw=1.5,linestyle="solid")
plt.plot(thermal_specah.w, thermal_specah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specai.w, thermal_specai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaj.w, thermal_specaj.r,"gray",lw=1.5,linestyle="solid")

plt.figure(figsize=(20, 12))

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 0 em graus e 0 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=0, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaa = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaa.plot()
# Out:
# /home/camila/.local/lib/python3.6/site-packages/cana/thermal/models.py:32: RuntimeWarning: overflow encountered in exp
#   aux = np.exp(h_planck * c_light / k_bol / wavelength / temp)

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 10 em graus e 0.1745 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/18, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaab = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaab.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 20 em graus e 0.349066 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/9, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaac = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaac.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 30 em graus e 0.523599 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/6, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaad = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaad.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 40 em graus e 0.698132 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=2*np.pi/9, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaae = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaae.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 45 em graus e 0.785398 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/4, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaf = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaf.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 50 em graus e 0.872665 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=5*np.pi/18, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaag = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaag.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 60 em graus e 1.0472 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/3, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaah = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaah.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 70 em graus e 1.22173 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=7*np.pi/18, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaai = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaai.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 80 em graus e 1.39626 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=4*np.pi/9, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaj = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaj.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase com 90 em graus e 1.5708 em radianos

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=np.pi/2, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaak = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaak.plot()

# %%
#Dados do Svea (da NASA) variando o ângulo de fase - todos

import matplotlib
import matplotlib.pyplot as plt
import numpy 
import numpy as np


matplotlib.pyplot.title("Asteroide Svea variando o ângulo de fase")
#matplotlib.pyplot.xlim(0.4,5.05)
#matplotlib.pyplot.ylim(-0.001,0.160)

matplotlib.pyplot.xlabel("Wavelength")
matplotlib.pyplot.ylabel("Reflectance")

plt.plot(thermal_specaaaa.w, thermal_specaaaa.r,"lime",lw=1.5,linestyle="solid")#b de azul e dashed de tracejado
plt.plot(thermal_specaaab.w, thermal_specaaab.r,"orange",lw=1.5,linestyle="solid")#r de vermelho e dotted de pontilhado
plt.plot(thermal_specaaac.w, thermal_specaaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaad.w, thermal_specaaad.r,"green",lw=1.5,linestyle="solid") #legenda
plt.plot(thermal_specaaae.w, thermal_specaaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaf.w, thermal_specaaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaag.w, thermal_specaaag.r,"deeppink",lw=1.5,linestyle="solid") #deeppink é um rosa forte
plt.plot(thermal_specaaah.w, thermal_specaaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaai.w, thermal_specaaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaj.w, thermal_specaaaj.r,"gray",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaak.w, thermal_specaaak.r,"black",lw=1.5,linestyle="solid")


plt.legend(["00º", "10º", "20º", "30º", "40º", "45º", "50º", "60º", "70º", "80º", "90º"], 
           loc = "upper left", bbox_to_anchor=(1, 1), shadow = True)

plt.plot(thermal_specaaaa.w, thermal_specaaaa.r,"lime",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaab.w, thermal_specaaab.r,"orange",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaac.w, thermal_specaaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaad.w, thermal_specaaad.r,"green",lw=1.5,linestyle="solid") 
plt.plot(thermal_specaaae.w, thermal_specaaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaf.w, thermal_specaaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaag.w, thermal_specaaag.r,"deeppink",lw=1.5,linestyle="solid") 
plt.plot(thermal_specaaah.w, thermal_specaaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaai.w, thermal_specaaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaj.w, thermal_specaaaj.r,"gray",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaak.w, thermal_specaaak.r,"black",lw=1.5,linestyle="solid")

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.01
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaa = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaa.plot()
# Out:
# /home/camila/.local/lib/python3.6/site-packages/cana/thermal/models.py:32: RuntimeWarning: overflow encountered in exp
#   aux = np.exp(h_planck * c_light / k_bol / wavelength / temp)

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.04
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaab = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaab.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.07
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaac = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaac.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.10
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaad = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaad.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.14
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaae = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaae.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.17
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaf = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaf.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.20
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaag = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaag.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.24
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaah = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaah.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.3
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaai = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaai.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.4
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaj = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaj.plot()

# %%
#Dados do Svea (da NASA) variando o albedo

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.5
diametro = 81.057
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaak = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaak.plot()

# %%
#Dados do Svea (da NASA) variando o albedo - todos

import matplotlib
import matplotlib.pyplot as plt
import numpy 
import numpy as np


matplotlib.pyplot.title("Asteroide Svea variando o albedo")
matplotlib.pyplot.xlim(0.4,5.05)
matplotlib.pyplot.ylim(-0.001,0.16)

matplotlib.pyplot.xlabel("Wavelength")
matplotlib.pyplot.ylabel("Reflectance")

plt.plot(thermal_specaaa.w, thermal_specaaa.r,"lime",lw=1.5,linestyle="solid")#b de azul e dashed de tracejado
plt.plot(thermal_specaab.w, thermal_specaab.r,"orange",lw=1.5,linestyle="solid")#r de vermelho e dotted de pontilhado
plt.plot(thermal_specaac.w, thermal_specaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaad.w, thermal_specaad.r,"green",lw=1.5,linestyle="solid") #legenda
plt.plot(thermal_specaae.w, thermal_specaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaf.w, thermal_specaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaag.w, thermal_specaag.r,"deeppink",lw=1.5,linestyle="solid") #deeppink é um rosa forte
plt.plot(thermal_specaah.w, thermal_specaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaai.w, thermal_specaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaj.w, thermal_specaaj.r,"gray",lw=1.5,linestyle="solid")
plt.plot(thermal_specaak.w, thermal_specaak.r,"black",lw=1.5,linestyle="solid")


plt.legend(["0.01", "0.04", "0.07", "0.10", "0.14", "0.17", "0.20", "0.24", "0.30", "0.40", "0.50"], 
           loc = "upper left", bbox_to_anchor=(1, 1), shadow = True)


plt.plot(thermal_specaaa.w, thermal_specaaa.r,"lime",lw=1.5,linestyle="solid")
plt.plot(thermal_specaab.w, thermal_specaab.r,"orange",lw=1.5,linestyle="solid")
plt.plot(thermal_specaac.w, thermal_specaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaad.w, thermal_specaad.r,"green",lw=1.5,linestyle="solid")
plt.plot(thermal_specaae.w, thermal_specaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaf.w, thermal_specaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaag.w, thermal_specaag.r,"deeppink",lw=1.5,linestyle="solid")
plt.plot(thermal_specaah.w, thermal_specaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaai.w, thermal_specaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaj.w, thermal_specaaj.r,"gray",lw=1.5,linestyle="solid")
plt.plot(thermal_specaak.w, thermal_specaak.r,"black",lw=1.5,linestyle="solid")


plt.figure(figsize=(20, 12))

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 10
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaaa = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaaa.plot()
# Out:
# /home/camila/.local/lib/python3.6/site-packages/cana/thermal/models.py:32: RuntimeWarning: overflow encountered in exp
#   aux = np.exp(h_planck * c_light / k_bol / wavelength / temp)

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 20
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaab = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaab.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 30
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaac = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaac.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 40
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaad = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaad.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 50
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaae = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaae.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 60
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaaf = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaaf.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 70
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaag = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaag.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 80
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaah = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaah.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 90
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaai = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaai.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro

import cana
import numpy as np
import matplotlib.pyplot as plt
from cana.datasets import getspectrum

r = 2.42
delta = 1.86

x = cana.NEATM(r, delta, phase_angle=22.26, eta=0.9, epsilon=0.9, G=0.15)

distancia_do_sol = 2.42
distancia_da_terra = 1.86
albedo = 0.039
diametro = 100
m = cana.NEATM(distancia_do_sol, distancia_da_terra)
wave = np.linspace(0.5, 5.0, 100)

thermal_specaaaaj = m.flux(albedo, diametro, wavelengths=wave)
thermal_specaaaaj.plot()

# %%
#Dados do Svea (da NASA) variando o diâmetro - todos

import matplotlib
import matplotlib.pyplot as plt
import numpy 
import numpy as np


matplotlib.pyplot.title("Asteroide Svea variando o diâmetro")
matplotlib.pyplot.xlim(0.4,5.05)
matplotlib.pyplot.ylim(-0.001,0.25)

matplotlib.pyplot.xlabel("Wavelength")
matplotlib.pyplot.ylabel("Reflectance")

plt.plot(thermal_specaaaaa.w, thermal_specaaaaa.r,"lime",lw=1.5,linestyle="solid")#b de azul e dashed de tracejado
plt.plot(thermal_specaaaab.w, thermal_specaaaab.r,"orange",lw=1.5,linestyle="solid")#r de vermelho e dotted de pontilhado
plt.plot(thermal_specaaaac.w, thermal_specaaaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaad.w, thermal_specaaaad.r,"green",lw=1.5,linestyle="solid") #legenda
plt.plot(thermal_specaaaae.w, thermal_specaaaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaaf.w, thermal_specaaaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaag.w, thermal_specaaaag.r,"deeppink",lw=1.5,linestyle="solid") #deeppink é um rosa forte
plt.plot(thermal_specaaaah.w, thermal_specaaaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaai.w, thermal_specaaaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaaj.w, thermal_specaaaaj.r,"gray",lw=1.5,linestyle="solid")


plt.legend(["10 km", "20 km", "30 km", "40 km", "50 km", "60 km", "70 km", "80 km", "90 km", "100 km"], 
           loc = "upper left", bbox_to_anchor=(1, 1), shadow = True)

plt.plot(thermal_specaaaaa.w, thermal_specaaaaa.r,"lime",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaab.w, thermal_specaaaab.r,"orange",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaac.w, thermal_specaaaac.r,"purple",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaad.w, thermal_specaaaad.r,"green",lw=1.5,linestyle="solid") 
plt.plot(thermal_specaaaae.w, thermal_specaaaae.r,"yellow",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaaf.w, thermal_specaaaaf.r,"red",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaag.w, thermal_specaaaag.r,"deeppink",lw=1.5,linestyle="solid") 
plt.plot(thermal_specaaaah.w, thermal_specaaaah.r,"brown",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaai.w, thermal_specaaaai.r,"blue",lw=1.5,linestyle="solid")
plt.plot(thermal_specaaaaj.w, thermal_specaaaaj.r,"gray",lw=1.5,linestyle="solid")
